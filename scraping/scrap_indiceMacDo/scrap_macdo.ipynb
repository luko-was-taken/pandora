# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://planificateur.a-contresens.net/classement_par_pays/indice_big_mac.html"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]>         <html class="ie8"> <![endif]-->
# <!--[if IE 9]>         <html class="ie9 gt-ie8"> <![endif]-->
# <!--[if (gte IE 9) | !(IE)]><!--> <html class="gt-ie8 gt-ie9 not-ie"> <!--<![endif]-->
# <head>
# <script charset="utf-8" src="https://choices.consentframework.com/js/pa/22499/c/jkIEq/stub" type="text/javascript"></script>
# <script>
# 	window.Sddan = {
# 		"info": {
# 			"si": "",
# 			"ft_arr_city" : "",
# 			"ft_arr_country" : "",
# 			"ft_dpt_city" : "",
# 			"ft_dpt_country" : "",
# 			"ft_end" : "",
# 			"ft_start" : "",
# 			"hd_m" : "",
# 			"hd_s256" : "",
# 		}
# 	}
# </script>
# <script async="" charset="utf-8" src="https://choices.consentframework.com/js/pa/22499/c/jkIEq/cmp" type="text/javascript"></script>
# <meta charset="utf-8"/>
# <!--[if IE]>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#         <![endif]-->
# <title>Classement des pays par coût d'un Big Mac (indice Big Mac) dans le monde</title>
# ...

# %%
ranking=soup.find('section',{'class':"ranking-map__panel"})
print(ranking)
